# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

respath = './results/output_E2USD/MoCap/amc_86_01.4d.npy'
res = np.load(respath)

# %%
res
# Out:
# array([[0, 0, 0, ..., 2, 2, 2],
#        [0, 0, 0, ..., 0, 0, 0]])

# %%
plt.plot(res[1])
plt.plot(res[0])
